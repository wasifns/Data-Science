# %%
#Regression Technique: 
#Dataset: Advertising 
#This data consists details of TV, Radio, Newspaper and sales.
#a. Apply Linear Regression using suitable library function 
#b. Assess the performance of regression models using MSE, MAE and R-Square metrics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model, metrics
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
#load the dataset
#define features and target variables
#split dataset into train and test
#initialise and train the linear regression model
#get model parameters (r^2,intersept,corf)
#make predictions on test set
#perform metrics
#plot training data and regression line

# %%
data = pd.read_csv("Advertising.csv")

# %%
x = data[["TV", "Radio", "Newspaper"]]
y = data['Sales']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = linear_model.LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mae = metrics.mean_absolute_error(y_test,y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-Squared Score (R^2):", r2)
# Out:
# Mean Absolute Error (MAE): 1.4607567168117606
# Mean Squared Error (MSE): 3.1740973539761046
# R-Squared Score (R^2): 0.899438024100912

# %%
print(len(x_train), len(y_train))  # Should print equal numbers
print(len(x_test), len(y_test))    # Should print equal numbers
# Out:
# 160 160
# 40 40

# %%
x_train = x_train.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)

# %%
x_test = x_test.to_numpy()
y_test = y_test.to_numpy()

# %%
x_test = x_test.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# %%
#OPTIONAL
# Scatter plot for TV vs Sales
plt.scatter(data["TV"], y, color='yellow')
plt.title("Sales vs TV Advertising Budget")
plt.xlabel("TV Advertising Budget")
plt.ylabel("Sales")
plt.show()

# Scatter plot for Radio vs Sales
plt.scatter(data["Radio"], y, color='blue')
plt.title("Sales vs Radio Advertising Budget")
plt.xlabel("Radio Advertising Budget")
plt.ylabel("Sales")
plt.show()

# Scatter plot for Newspaper vs Sales
plt.scatter(data["Newspaper"], y, color='purple')
plt.title("Sales vs Newspaper Advertising Budget")
plt.xlabel("Newspaper Advertising Budget")
plt.ylabel("Sales")
plt.show()

# %%
# Combine X and y into a single DataFrame for pair plotting
data["Sales"] = y
sns.pairplot(data, x_vars=["TV", "Radio", "Newspaper"], y_vars="Sales", height=4, aspect=1)
plt.show()
